# %% [markdown]
# ### 1st Jupyter NoteBook
# This is a sample jupyter notebook

# %%
print('hello Jupyter')

x=5
y=6
z=x*y
print(z)
# Out:
# hello Jupyter
# 30

# %% [markdown]
# ### Steps for setup jupyter
# 1. install a extension --- jupyter
# 2. write in terminal --- pip install jupyter
# 3. to update, run: python.exe -m pip install --upgrade pip
# 4. make a file with extension--- .ipynb
